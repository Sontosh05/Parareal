# %%
using LinearAlgebra, Plots

# %%
function FE(f, a, b, u0, N) where T<:AbstractFloat
    ndf = length(u0)
    u = zeros(N+1)
    dt = (b-a)/N
    t = Vector(range(a, b, length=N+1))
    u[1] = u0
    for i in 1:N
        u[i+1] = u[i] .+ dt * f(t[i], u[i])
    end
    return t, u
end
# Out:
# FE (generic function with 2 methods)

# %%
# Store Fine Solution
a=0
b=10
u0=1
f(t, u)= u*cos(t)
texact, uexact=FE(f, a, b, u0, 1800)
# Out:
# ([0.0, 0.005555555555555556, 0.011111111111111112, 0.016666666666666666, 0.022222222222222223, 0.027777777777777776, 0.03333333333333333, 0.03888888888888889, 0.044444444444444446, 0.05  …  9.95, 9.955555555555556, 9.96111111111111, 9.966666666666667, 9.972222222222221, 9.977777777777778, 9.983333333333333, 9.988888888888889, 9.994444444444444, 10.0], [1.0, 1.0055555555555555, 1.0111418890986823, 1.0167589972852091, 1.0224068738631351, 1.028085509630413, 1.0337948923926665, 1.0395350069208535, 1.0453058349088822, 1.0511073549311911  …  0.6001045129331496, 0.5972199684625066, 0.5943585757488539, 0.5915202224121954, 0.5887047961417178, 0.5859121847115925, 0.5831422759965043, 0.5803949579869091, 0.5776701188040225, 0.5749676467145425])

# %%
function parareal(a, b, u0, N, F, G, K)
    tval=Vector(range(a, b, N+1))
    Ufine=zeros(N+1)
    Ufine[1] = u0
    for i in 1:N
        Ufine[i+1] = F(tval[i], tval[i+1], Ufine[i])
    end
    Uk=[Vector{Float64}(undef, N+1) for k in 1:K+1]
    for k in 1:K+1
        Uk[k][1]=u0
    end
    for j in 1:N
        #Uk[1][j+1]=G(tval[j], tval[j+1], Uk[1][j])
        Uk[1][j+1]=10.0 # may take random initial guess
    end
    for k in 1:K
        for i in 1:N
            
            Fk0=F(tval[i], tval[i+1], Uk[k][i])
            Gk0=G(tval[i], tval[i+1], Uk[k][i])
            Gk1=G(tval[i], tval[i+1], Uk[k+1][i])
            
            Uk[k+1][i+1]=Fk0 + Gk1 - Gk0
        end
    end
    
    return Uk, Ufine, tval
end
# Out:
# parareal (generic function with 3 methods)

# %%
function Fs(a, b, u0) where T<:AbstractFloat
    t, u=FE(f, a, b, u0, 10)
    return u[end]
end
# Out:
# Fs (generic function with 2 methods)

# %%
function Gs(a, b, u0) where T<:AbstractFloat
    t, u=FE(f,  a, b, u0, 1)
    return u[end]
end
# Out:
# Gs (generic function with 2 methods)

# %%
a=0
b=10
u0=1

K=15 # Number of iteration

N = 180

err=zeros(K+1)
# Parareal Solution

    Uk, Ufine, tval=parareal(a, b, u0, N, Fs, Gs, K)

    # stroing errors
    
    for k in 1:K+1
        err[k]=norm(Uk[k] - Ufine)
    end



using Plots
plot(err, yaxis=:log, xlabel="Number of iterations", ylabel="error", label="N=3^3", title="Double precision parareal")
